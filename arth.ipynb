# %%
# Arthematic_opr
n1=400
n2=250
print(n1+n2)
print(n1-n2)
print(n1/n2)
print(n1%n2)
print(n1*n2)
print(n1//n2)
print(n1**3)
# Out:
# 650
# 150
# 1.6
# 150
# 100000
# 1
# 64000000

# %%
# Assign_Op
a=1200
a%=40



print(a)
# Out:
# 0

# %%
# Comparison_Ops
a=89
b=89.01
print(a==b)
print(a>b)
print(a<b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# False
# False
# True
# True
# False
# True

# %%
# Logical_opr
a=38.9
b=32.8
c=33.7
not(a>b and b<c and c<a)
# Out:
# False

# %%
# Identity_Opr>>In same memory location
a=29.7
b=29.07
not(a is  b)
# Out:
# True

# %%
# Membership_opr
a=["apple","banana","guava","apricot"]
b="apple"
c="pomogranate"

c not in a
# Out:
# True

# %%
n1=20
n2=45
sum=n1+n2
print(sum)
# Out:
# 65

# %%
# Arthematic
# Assignment
# Comparison
